# %% [markdown]
# <h1>Posttest Praktikum Sistem Informasi </h1>
#
# NIM **2109116014**
#
# NAMA **WINDY WIDYASTUTIK**

# %% [markdown]
# ## Business Understanding & Data Understanding

# %%
# import library
import pandas as pd 
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv("ChurnBank.csv")

# %%
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# 1       Uneducated        Married     $60K - $80K          Blue        2527.0
# 2          College         Single    $80K - $120K          Blue        3495.0
# 3      High School        Unknown         $120K +          Blue        7793.0
# 4         Graduate         Single  Less than $40K          Blue        2761.0
# 5    Post-Graduate        Unknown    $80K - $120K          Blue       23714.0
# 6      High School         Single     $60K - $80K          Blue       24621.0
# 7         Graduate         Single  Less than $40K          Blue        2370.0
# 8       Uneducated        Married         Unknown          Blue        2404.0
# 9          Unknown         Single    $80K - $120K          Blue        4742.0
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# 12     High School        Married         Unknown          Blue        5245.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3
# 19   Post-Graduate        Married         Unknown          Blue        2953.0

# %% [markdown]
# ### Business Understanding
#
# **Tujuan Penggunaan Dataset**
#
# Dengan dataset yang ada bertujuan untuk dapat menghitung klasifikasi data dari nasabah yang ada dengan menggunakan algoritma Naive Bayes.
#
# **Tujuan Perusahaan**
#
# Misalnya pada sebuah perusahaan perbankan yang memiliki tujuan dalam penentuan nasabah dalam menerima asuransi yang tepat dengan menggunakan algoritma Naive Bayes.
#
# **Tujuan Penggunaan Naive Bayes**
#
# Tujuan dari penggunaan algoritma naive bayes dalam perusahaan adalah untuk memprediksi data nasabah dengan tepat. Dengan menggunakan naive bayes hasil yang didapatkan akan lebih akurat sehingga perusahaan mampu mempertimbangkan asuransi kepada nasabah dengan tepat sasaran.

# %% [markdown]
# ### Data Understanding

# %%
# df1 merupakan dataset dengan label target AttiredCustomer
df1= df[df["Attrition_Flag"] == "Attrited Customer"]
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# 2         College         Single    $80K - $120K          Blue        3495.0
# 3     High School        Unknown         $120K +          Blue        7793.0
# 4        Graduate         Single  Less than $40K          Blue        2761.0
# 5   Post-Graduate        Unknown    $80K - $120K          Blue       23714.0
# 6     High School         Single     $60K - $80K          Blue       24621.0
# 7        Graduate         Single  Less than $40K          Blue        2370.0
# 8      Uneducated        Married         Unknown          Blue        2404.0
# 9         Unknown         Single    $80K - $120K          Blue        4742.0

# %%
# df2 merupakan dataset dengan label bukan target AttiredCustomer
df2= df[df["Attrition_Flag"] != "Attrited Customer"]
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# 12     High School        Married         Unknown          Blue        5245.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3
# 19   Post-Graduate        Married         Unknown          Blue        2953.0

# %%
# df3 merupakan tabel untuk usia dibawah 50 tahun
df3= df[df["Customer_Age"] < 50 ]
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# 3      High School        Unknown         $120K +          Blue        7793.0
# 4         Graduate         Single  Less than $40K          Blue        2761.0
# 9          Unknown         Single    $80K - $120K          Blue        4742.0
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 12     High School        Married         Unknown          Blue        5245.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 15        Graduate        Married  Less than $40K          Blue        3111.0
# 16        Graduate        Married  Less than $40K          Blue        7562.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3

# %%
# df4 merupakan tabel untuk customer yang statusnya single
df4= df[df["Marital_Status"] == "Single"]
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# 2          College         Single    $80K - $120K          Blue        3495.0
# 4         Graduate         Single  Less than $40K          Blue        2761.0
# 6      High School         Single     $60K - $80K          Blue       24621.0
# 7         Graduate         Single  Less than $40K          Blue        2370.0
# 9          Unknown         Single    $80K - $120K          Blue        4742.0
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 13      Uneducated         Single     $60K - $80K          Blue       18584.0
# 14      Uneducated         Single         Unknown          Blue        2429.0
# 17     High School         Single  Less than $40K          Blue        1438.3
# 18        Graduate         Single     $60K - $80K          Blue        1438.3

# %%
# Tampilkan info dataset (df.info()) dan berikan penjelasannya dalam bentuk teks atau comment
# Menampilkan info dataset
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# Dataset diatas menampilkan informasi detail tentang dataframe, seperti jumlah baris data, nama-nama kolom berserta jumlah data dan tipe datanya.
#
# Dimana baris data berjumlah 20 baris yang memiliki 10 kolom, yaitu CLIENTNUM bertipe data int, Attrition_Flag bertipe data object, Customer_Age bertipe data int, Gender bertipe data object, Education_Level bertipe data object, Marital_Status bertipe data object, Income_Category bertipe data object, Card_Category bertipe data object, dan Credit_Limit bertipe data float.

# %% [markdown]
# #### Opsional (nilai plus)

# %%
# Menampilkan kolom bertipe angka
df5= df[['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit']]

# %%
# Menampilkan nilai rata-rata Kolom yang bertipe angka
df5.mean()
# Out:
# Unnamed: 0      6.105100e+03
# CLIENTNUM       7.424893e+08
# Customer_Age    4.725000e+01
# Credit_Limit    8.114580e+03
# dtype: float64

# %%
# Menampilkan nilai min Kolom yang bertipe angka
df5.min()
# Out:
# Unnamed: 0            176.0
# CLIENTNUM       709222008.0
# Customer_Age           32.0
# Credit_Limit         1438.3
# dtype: float64

# %%
# Menampilkan nilai max Kolom yang bertipe angka
df5.max()
# Out:
# Unnamed: 0          10084.0
# CLIENTNUM       809844108.0
# Customer_Age           59.0
# Credit_Limit        26792.0
# dtype: float64

# %%
# Menampilkan nilai standar deviasi Kolom yang bertipe angka
df5.std()
# Out:
# Unnamed: 0      2.850304e+03
# CLIENTNUM       4.045524e+07
# Customer_Age    7.859791e+00
# Credit_Limit    8.331037e+03
# dtype: float64

# %%
# Atau juga bisa langsung menggunakan
df.describe()
# Out:
#          Unnamed: 0     CLIENTNUM  Customer_Age  Credit_Limit
# count     20.000000  2.000000e+01     20.000000     20.000000
# mean    6105.100000  7.424893e+08     47.250000   8114.580000
# std     2850.304026  4.045524e+07      7.859791   8331.036819
# min      176.000000  7.092220e+08     32.000000   1438.300000
# 25%     4695.750000  7.120726e+08     41.000000   2502.500000
# 50%     6299.000000  7.173934e+08     47.500000   4118.500000
# 75%     8206.500000  7.822994e+08     53.500000   8621.000000
# max    10084.000000  8.098441e+08     59.000000  26792.000000

# %% [markdown]
# #### Explore Data

# %% [markdown]
# ##### Visualisasi Comparision

# %%
# Visualisasi yang menampilkan berapa banyak yang attired customer dan tidak
sns.countplot(data=df,x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya
sns.countplot(data=df, y="Education_Level")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %%
# Visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
sns.countplot(data=df, y="Education_Level", hue="Gender")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %% [markdown]
# - Visualisasi ini membandingkan banyaknya jenis nasabah yang attrited customer dan yang bukan attrited customer yaitu existing customer, dengan menggunakan visualisasi countplot.
#
# - Dengan method countplot menampilkan banyak nya objek Education level berdasarkan kategorinya.
#
# - Ditambahkan variabel hue untuk menunjukan subplot relasi antar variabel yang lebih jelas.
#
# **Penjelasan**
#
# 1. Visualisasi pertama : menampilkan visualisasi countplot dari dataset df dengan variabel x dari kolom "Attrition_Flag", sehingga menghasilkan tampilan dua bar secara vertikal.
# 2. Visualisasi kedua : menampilkan visualisasi countplot dari dataset df dengan varibel y dari kolom "Education_Level", sehingga menghasilkan tampilan tujuh bar (sesuai kategorinya) secara horizontal.
# 3. Visualisasi ketiga : menampilkan visualisasi count dari dataset df dengan variabel y dari kolom "Education_Level" berdasarkan *second category* (hue) "Gender".

# %% [markdown]
# ##### Visualisasi Distribution

# %%
# Buatlah historgram untuk credit card limit
sns.histplot(data=df,x="Credit_Limit", kde=True)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
# Buatlah historgram untuk customer age
sns.histplot(data=df,x="Customer_Age", kde=True)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
# Buatlah boxplot untuk customer age
sns.boxplot(data=df,x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %%
# Buatlah boxplot untuk credit card limit
sns.boxplot(data=df,x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %% [markdown]
# - Pada histogram sumbu x merepresentasikan bin dari data dan sumbu y dari histogram merepresentasikan frekuensi dari setiap bin.
#
# - Dengan menentukan nilai parameter x menggunakan data dari df maka sudah dapat menghasilkan boxplot untuk customer dan credit card limit.
#
# **Penjelasan**
# 1. Visualiasi pertama : menampilkan visualisasi hitsplot dari dataset df dengan variabel x dari kolom "Credit_Limit" dan kernel density estimate (kde).
# 2. Visualiasi kedua : menampilkan visualisasi hitsplot dari dataset df dengan variabel x dari kolom "Customer_Age" dan kernel density estimate (kde).
# 3. Visualiasi ketiga : menampilkan visualisasi boxplot dari dataset df dengan variabel x dari kolom "Customer_Age".
# 4. Visualiasi keempat : menampilkan visualisasi boxplot dari dataset df dengan variabel x dari kolom "Credit_Limit".

# %% [markdown]
# ##### Visualisasi Relationship

# %%
# Buatlah scatterplot untuk customer Age dan credit card limit
sns.scatterplot(data=df,x="Customer_Age",y="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# ##### Visualisasi Composition

# %%
# Buatlah pieplot untuk Income Category 
px.pie(df,names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c20ae741-5032-412d-adb8-5af355162780" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c20ae741-5032-412d-adb8-5af355162780")) {                    Plotly.newPlot(                        "c20ae741-5032-412d-adb8-5af355162780",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Income_Category=%{label}<extra></extra>","labels":["$40K - $60K","$60K - $80K","$80K - $120K","$120K +","Less than $40K","$80K - $120K","$60K - $80K","Less than $40K","Unknown","$80K - $120K","$60K - $80K","$80K - $120K","Unknown","$60K - $80K","Unknown","Less than $40K","Less than $40K","Less than $40K","$60K - $80K","Unknown"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"m ...

# %%
# Buatlah pieplot untuk  Education Level
px.pie(df,names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="80fdd74a-a308-4a79-91bb-50e39d29f96c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80fdd74a-a308-4a79-91bb-50e39d29f96c")) {                    Plotly.newPlot(                        "80fdd74a-a308-4a79-91bb-50e39d29f96c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Education_Level=%{label}<extra></extra>","labels":["Unknown","Uneducated","College","High School","Graduate","Post-Graduate","High School","Graduate","Uneducated","Unknown","Doctorate","Uneducated","High School","Uneducated","Uneducated","Graduate","Graduate","High School","Graduate","Post-Graduate"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinew ...

# %% [markdown]
# ### Opsional (Nilai Plus)

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
#sns.boxplot(data=df, x="Credit_Limit", y = "Gender", color="pink" )
sns.boxplot(data=df, x="Credit_Limit", hue="Gender", color="pink" )
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x="Credit_Limit", y="Attrition_Flag", hue="Attrition_Flag", color="pink" )
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x="Customer_Age", y="Attrition_Flag", hue="Attrition_Flag", color="pink" )
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df, x="Attrition_Flag", hue="Gender", color="pink" )
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada
sns.heatmap(df5.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %% [markdown]
# ### dataset

# %%
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

df_baru = df.drop(["Unnamed: 0", "CLIENTNUM", "Customer_Age", "Credit_Limit"], axis=1)

# %%
# Memasukkan df_baru ke dalam file csv
df_baru.to_csv('df_baru.csv')

# %%
# Membaca file csv
df_baru = pd.read_csv("df_baru.csv")

# %%
def naive_bayes(prediksi:list)-> tuple :
    attrited = df_baru[df_baru["Attrition_Flag"]=="Attrited Customer"]
    existing = df_baru[df_baru["Attrition_Flag"]=="Existing Customer"]
    
    # prior probability
    attrited_prior = len(attrited) / len(df_baru)
    existing_prior = len(existing) / len(df_baru)
    
    # likelihood
    for i in range(len(prediksi)):
        attrited_subset = attrited[attrited.iloc[:,i]==prediksi[i]]
        existing_subset = existing[existing.iloc[:,i]==prediksi[i]]
        
        attrited_posterior = (len(attrited_subset) + 1) / (len(attrited) + len(df_baru.iloc[:,i].unique()))
        existing_posterior = (len(existing_subset) + 1) / (len(existing) + len(df_baru.iloc[:,i].unique()))
        
        if i == 0:
            attrited_likelihood = attrited_posterior
            existing_likelihood = existing_posterior
        else:
            attrited_likelihood *= attrited_posterior
            existing_likelihood *= existing_posterior
    
    # posterior probability
    attrited_posterior = attrited_prior * attrited_likelihood
    existing_posterior = existing_prior * existing_likelihood
    
    # normalize posterior probability
    persentasenya = existing_posterior / (attrited_posterior + existing_posterior)
    hasilnya = "Existing Customer" if persentasenya >= 0.5 else "Attrited Customer"
    
    return (hasilnya, persentasenya)

# %%
hasil = naive_bayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
print(hasil)
# Out:
# ('Attrited Customer', 0.25)
